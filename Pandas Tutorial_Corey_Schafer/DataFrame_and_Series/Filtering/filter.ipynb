# %%
people = {
    "first" : ['Corey', 'Jane', 'John'],
    "last" : ['Schafer', 'Doe', 'Doe'],
    "email" : ['CoreyMSchafer@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df.head()
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %%
df['last'] == 'Doe'
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
filter = df['last'] == 'Doe'

# %%
filter
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
df[filter]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@gmail.com
# 2  John  Doe  JohnDoe@gmail.com

# %%
df.loc[filter]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@gmail.com
# 2  John  Doe  JohnDoe@gmail.com

# %%
df.loc[filter, 'email']
# Out:
# 1    JaneDoe@gmail.com
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %%
filter = (df['last'] == 'Doe') & (df['first'] == 'John')

# %%
filter
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
df[~filter]
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com

# %%
df[filter]
# Out:
#   first last              email
# 2  John  Doe  JohnDoe@gmail.com

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                  Professional  \
# Respondent
# 1                                                     Student
# 2                                                     Student
# 3                                      Professional developer
# 4           Professional non-developer who sometimes write...
# 5                                      Professional developer
#
#                          ProgramHobby         Country      University  \
# Respondent
# 1                           Yes, both   United States              No
# 2                           Yes, both  United Kingdom  Yes, full-time
# 3                           Yes, both  United Kingdom              No
# 4                           Yes, both   United States              No
# 5           Yes, I program as a hobby     Switzerland              No
#
#                                   EmploymentStatus  \
# Respondent
# 1           Not employed, and not looking for work
# 2                               Employed part-time
# 3                               Employed full-time
# 4                               Employed full-time
# 5                               Employed full-time
#
#                                               FormalEducation  \
# Respondent
# 1                                            Secondary school
# 2           Some college/university study without earning ...
# 3                                           Bachelor's degree
# 4                                             Doctoral degree
# 5                                             Master's degree
#
#                                            MajorUndergrad  \
# Respondent
# 1                                                     NaN
# 2                Computer science or software engineering
# 3                Computer science or software engineering
# 4           A non-computer-focused engineering discipline
# 5                Computer science or software engineering
#
#                                                    HomeRemote  \
# Respondent
# 1                                                         NaN
# 2                       More than half, but not all, the time
# 3           Less than half the time, but at least one day ...
# 4           Less than half the time, but at least one day ...
# 5                                                       Never
#
#                          CompanySize  \
# Respondent
# 1                                NaN
# 2                 20 to 99 employees
# 3           10,000 or more employees
# 4           10,000 or more employees
# 5                 10 to 19 employees
#
#                                                   CompanyType  \
# Respondent
# 1                                                         NaN
# 2           Privately-held limited company, not in startup...
# 3                                 Publicly-traded corporation
# 4           Non-profit/non-governmental organization or pr...
# 5           Privately-held limited company, not in startup...
#
#                 YearsProgram     YearsCodedJob YearsCodedJobPast  \
# Respondent
# 1               2 to 3 years               NaN               NaN
# 2              9 to 10 years               NaN               NaN
# 3           20 or more years  20 or more years               NaN
# 4             14 to 15 years     9 to 10 years               NaN
# 5           20 or more years    10 to 11 years               NaN
#
#                                                 DeveloperType  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                       Other
# 4                                                         NaN
# 5           Mobile developer; Graphics programming; Deskto...
#
#            WebDeveloperType MobileDeveloperType NonDeveloperType  \
# Respondent
# 1                       NaN                 NaN              NaN
# 2                       NaN                 NaN              NaN
# 3                       NaN                 NaN              NaN
# 4                       NaN                 NaN   Data scientist
# 5                       NaN                 NaN              NaN
#
#             CareerSatisfaction  JobSatisfaction ExCoderReturn ExCoderNotForMe  \
# Respondent
# 1                          NaN              NaN           NaN             NaN
# 2                          NaN              NaN           NaN             NaN
# 3                          8.0              9.0           NaN             NaN
# 4                          6.0              3.0           NaN             NaN
# 5                          6.0              8.0           NaN             NaN
#
#            ExCoderBalance ExCoder10Years ExCoderBelonged ExCoderSkills  \
# Respondent
# 1                     NaN            NaN             NaN           NaN
# 2                     NaN            NaN             NaN           NaN
# 3                     NaN            NaN             NaN           NaN
# 4                     NaN            NaN             NaN           NaN
# 5                     NaN            NaN             NaN           NaN
#
#            ExCoderWillNotCode ExCoderActive                  PronounceGIF  \
# Respondent
# 1                         NaN           NaN  With a soft "g," like "jiff"
# 2                         NaN           NaN  With a hard "g," like "gift"
# 3                         NaN           NaN  With a hard "g," like "gift"
# 4                         NaN           NaN  With a soft "g," like "jiff"
# 5                         NaN           NaN  With a soft "g," like "jiff"
#
#             ProblemSolving  BuildingThings LearningNewTech   BoringDetails  \
# Respondent
# 1           Strongly agree  Strongly agree           Agree        Disagree
# 2                      NaN             NaN             NaN             NaN
# 3           Strongly agree  Strongly agree  Strongly agree  Somewhat agree
# 4           Strongly agree  Strongly agree  Strongly agree        Disagree
# 5                      NaN             NaN             NaN             NaN
#
#                JobSecurity DiversityImportant AnnoyingUI FriendsDevelopers  \
# Respondent
# 1           Strongly agree              Agree      Agree          Disagree
# 2                      NaN                NaN        NaN               NaN
# 3                    Agree     Strongly agree      Agree    Somewhat agree
# 4           Somewhat agree              Agree      Agree             Agree
# 5                      NaN                NaN        NaN               NaN
#
#              RightWrongWay UnderstandComputers     SeriousWork  \
# Respondent
# 1           Somewhat agree            Disagree  Strongly agree
# 2                      NaN                 NaN             NaN
# 3                 Disagree            Disagree           Agree
# 4           Somewhat agree   Strongly disagree  Strongly agree
# 5                      NaN                 NaN             NaN
#
#            InvestTimeTools        WorkPayCare KinshipDevelopers  ...  \
# Respondent                                                       ...
# 1           Strongly agree  Strongly disagree             Agree  ...
# 2                      NaN                NaN               NaN  ...
# 3           Somewhat agree           Disagree    Somewhat agree  ...
# 4                    Agree           Disagree    Strongly agree  ...
# 5                      NaN                NaN               NaN  ...
#
#            EquipmentSatisfiedStorage EquipmentSatisfiedRW   InfluenceInternet  \
# Respondent
# 1                     Very satisfied            Satisfied  Not very satisfied
# 2                          Satisfied   Somewhat satisfied           Satisfied
# 3                          Satisfied   Somewhat satisfied      Very satisfied
# 4                                NaN                  NaN                 NaN
# 5                          Satisfied            Satisfied           Satisfied
#
#            InfluenceWorkstation    InfluenceHardware     InfluenceServers  \
# Respondent
# 1                           NaN                  NaN                  NaN
# 2           No influence at all  No influence at all  No influence at all
# 3            A lot of influence       Some influence       Some influence
# 4                           NaN                  NaN                  NaN
# 5                           NaN                  NaN                  NaN
#
#              InfluenceTechStack    InfluenceDeptTech    InfluenceVizTools  \
# Respondent
# 1                           NaN                  NaN                  NaN
# 2           No influence at all  No influence at all  No influence at all
# 3                Some influence   A lot of influence       Some influence
# 4                           NaN                  NaN                  NaN
# 5                           NaN                  NaN                  NaN
#
#               InfluenceDatabase       InfluenceCloud InfluenceConsultants  \
# Respondent
# 1                           NaN                  NaN                  NaN
# 2           No influence at all  No influence at all  No influence at all
# 3                Some influence       Some influence       Some influence
# 4                           NaN                  NaN                  NaN
# 5                           NaN                  NaN                  NaN
#
#            InfluenceRecruitment InfluenceCommunication  \
# Respondent
# 1                           NaN                    NaN
# 2           No influence at all    No influence at all
# 3                Some influence         Some influence
# 4                           NaN                    NaN
# 5                           NaN                    NaN
#
#                                        StackOverflowDescribes  \
# Respondent
# 1           I have created a CV or Developer Story on Stac...
# 2           I have created a CV or Developer Story on Stac...
# 3           I have created a CV or Developer Story on Stac...
# 4           I have created a CV or Developer Story on Stac...
# 5                                                         NaN
#
#            StackOverflowSatisfaction  \
# Respondent
# 1                                9.0
# 2                                8.0
# 3                                8.0
# 4                               10.0
# 5                                NaN
#
#                                          StackOverflowDevices  \
# Respondent
# 1                                            Desktop; iOS app
# 2           Desktop; iOS browser; iOS app; Android browser...
# 3                               Desktop; iOS browser; iOS app
# 4                               Desktop; iOS browser; iOS app
# 5                                                         NaN
#
#            StackOverflowFoundAnswer StackOverflowCopiedCode  \
# Respondent
# 1           At least once each week     Haven't done at all
# 2                     Several times           Several times
# 3                     Once or twice     Haven't done at all
# 4           At least once each week           Several times
# 5                               NaN                     NaN
#
#             StackOverflowJobListing StackOverflowCompanyPage  \
# Respondent
# 1                     Once or twice      Haven't done at all
# 2                     Once or twice            Once or twice
# 3               Haven't done at all      Haven't done at all
# 4           At least once each week            Several times
# 5                               NaN                      NaN
#
#              StackOverflowJobSearch StackOverflowNewQuestion  \
# Respondent
# 1               Haven't done at all            Several times
# 2                     Once or twice      Haven't done at all
# 3               Haven't done at all      Haven't done at all
# 4           At least once each week            Several times
# 5                               NaN                      NaN
#
#                StackOverflowAnswer    StackOverflowMetaChat  \
# Respondent
# 1                    Several times            Once or twice
# 2                    Several times  At least once each week
# 3           At least once each day   At least once each day
# 4           At least once each day   At least once each day
# 5                              NaN                      NaN
#
#            StackOverflowAdsRelevant StackOverflowAdsDistracting  \
# Respondent
# 1                    Somewhat agree           Strongly disagree
# 2                          Disagree           Strongly disagree
# 3                          Disagree                    Disagree
# 4                             Agree           Strongly disagree
# 5                               NaN                         NaN
#
#            StackOverflowModeration StackOverflowCommunity  \
# Respondent
# 1                Strongly disagree         Strongly agree
# 2                Strongly disagree         Strongly agree
# 3                Strongly disagree         Strongly agree
# 4                Strongly disagree         Strongly agree
# 5                              NaN                    NaN
#
#            StackOverflowHelpful StackOverflowBetter StackOverflowWhatDo  \
# Respondent
# 1                         Agree      Strongly agree      Strongly agree
# 2                         Agree      Strongly agree      Strongly agree
# 3                         Agree               Agree               Agree
# 4                Strongly agree               Agree      Strongly agree
# 5                           NaN                 NaN                 NaN
#
#            StackOverflowMakeMoney Gender HighestEducationParents  \
# Respondent
# 1               Strongly disagree   Male             High school
# 2               Strongly disagree   Male       A master's degree
# 3                        Disagree   Male   A professional degree
# 4                        Disagree   Male       A doctoral degree
# 5                             NaN    NaN                     NaN
#
#                                     Race         SurveyLong  \
# Respondent
# 1           White or of European descent  Strongly disagree
# 2           White or of European descent     Somewhat agree
# 3           White or of European descent     Somewhat agree
# 4           White or of European descent              Agree
# 5                                    NaN                NaN
#
#            QuestionsInteresting QuestionsConfusing InterestedAnswers  \
# Respondent
# 1                Strongly agree           Disagree    Strongly agree
# 2                Somewhat agree           Disagree    Strongly agree
# 3                         Agree           Disagree             Agree
# 4                         Agree     Somewhat agree    Strongly agree
# 5                           NaN                NaN               NaN
#
#               Salary ExpectedSalary
# Respondent
# 1                NaN            NaN
# 2                NaN        37500.0
# 3           113750.0            NaN
# 4                NaN            NaN
# 5                NaN            NaN
#
# [5 rows x 153 columns]

# %%
high_salary = (df['Salary'] > 70000)

# %%
df.loc[high_salary]
# Out:
#                       Professional                               ProgramHobby  \
# Respondent
# 3           Professional developer                                  Yes, both
# 15          Professional developer                  Yes, I program as a hobby
# 18          Professional developer                                  Yes, both
# 19          Professional developer                  Yes, I program as a hobby
# 23          Professional developer                                         No
# ...                            ...                                        ...
# 51316       Professional developer                                  Yes, both
# 51320       Professional developer                                  Yes, both
# 51336       Professional developer                  Yes, I program as a hobby
# 51372       Professional developer                                         No
# 51379       Professional developer  Yes, I contribute to open source projects
#
#                    Country      University    EmploymentStatus  \
# Respondent
# 3           United Kingdom              No  Employed full-time
# 15          United Kingdom              No  Employed full-time
# 18           United States  Yes, part-time  Employed full-time
# 19           United States              No  Employed full-time
# 23                  Israel              No  Employed full-time
# ...                    ...             ...                 ...
# 51316        United States              No  Employed full-time
# 51320        United States              No  Employed full-time
# 51336       United Kingdom              No  Employed full-time
# 51372          Netherlands              No  Employed full-time
# 51379               Cyprus              No  Employed part-time
#
#                 FormalEducation  \
# Respondent
# 3             Bachelor's degree
# 15          Professional degree
# 18            Bachelor's degree
# 19            Bachelor's degree
# 23            Bachelor's degree
# ...                         ...
# 51316           Doctoral degree
# 51320         Bachelor's degree
# 51336          Secondary school
# 51372         Bachelor's degree
# 51379          Secondary school
#
#                                                MajorUndergrad  \
# Respondent
# 3                    Computer science or software engineering
# 15          Computer engineering or electrical/electronics...
# 18                   Computer science or software engineering
# 19                   Computer science or software engineering
# 23          Computer engineering or electrical/electronics...
# ...                                                       ...
# 51316                Computer science or software engineering
# 51320                Computer science or software engineering
# 51336                                                     NaN
# 51372                Computer science or software engineering
# 51379                                                     NaN
#
#                                                    HomeRemote  \
# Respondent
# 3           Less than half the time, but at least one day ...
# 15          All or almost all the time (I'm full-time remote)
# 18          All or almost all the time (I'm full-time remote)
# 19                                      A few days each month
# 23                                      A few days each month
# ...                                                       ...
# 51316                                   A few days each month
# 51320                                   A few days each month
# 51336       Less than half the time, but at least one day ...
# 51372       All or almost all the time (I'm full-time remote)
# 51379       All or almost all the time (I'm full-time remote)
#
#                          CompanySize  \
# Respondent
# 3           10,000 or more employees
# 15          5,000 to 9,999 employees
# 18          1,000 to 4,999 employees
# 19          10,000 or more employees
# 23              500 to 999 employees
# ...                              ...
# 51316       10,000 or more employees
# 51320       10,000 or more employees
# 51336       1,000 to 4,999 employees
# 51372        Fewer than 10 employees
# 51379        Fewer than 10 employees
#
#                                                   CompanyType  \
# Respondent
# 3                                 Publicly-traded corporation
# 15                                Publicly-traded corporation
# 18                                Publicly-traded corporation
# 19                                Publicly-traded corporation
# 23          Privately-held limited company, not in startup...
# ...                                                       ...
# 51316                             Publicly-traded corporation
# 51320                             Publicly-traded corporation
# 51336                             Publicly-traded corporation
# 51372                                    Pre-series A startup
# 51379       Non-profit/non-governmental organization or pr...
#
#                 YearsProgram     YearsCodedJob YearsCodedJobPast  \
# Respondent
# 3           20 or more years  20 or more years               NaN
# 15          20 or more years  20 or more years               NaN
# 18          20 or more years  20 or more years               NaN
# 19              2 to 3 years      3 to 4 years               NaN
# 23            10 to 11 years      5 to 6 years               NaN
# ...                      ...               ...               ...
# 51316       20 or more years    10 to 11 years               NaN
# 51320           3 to 4 years  Less than a year               NaN
# 51336           8 to 9 years      8 to 9 years               NaN
# 51372         10 to 11 years      5 to 6 years               NaN
# 51379           5 to 6 years      5 to 6 years               NaN
#
#                                                 DeveloperType  \
# Respondent
# 3                                                       Other
# 15                    Embedded applications/devices developer
# 18          Web developer; Embedded applications/devices d...
# 19                                              Web developer
# 23                                                      Other
# ...                                                       ...
# 51316       Developer with a statistics or mathematics bac...
# 51320       Developer with a statistics or mathematics bac...
# 51336           Web developer; Desktop applications developer
# 51372       Web developer; Machine learning specialist; De...
# 51379                     Mobile developer; DevOps specialist
#
#                     WebDeveloperType MobileDeveloperType NonDeveloperType  \
# Respondent
# 3                                NaN                 NaN              NaN
# 15                               NaN                 NaN              NaN
# 18                               NaN                 NaN              NaN
# 19          Full stack Web developer                 NaN              NaN
# 23                               NaN                 NaN              NaN
# ...                              ...                 ...              ...
# 51316                            NaN                 NaN              NaN
# 51320                            NaN                 NaN              NaN
# 51336                            NaN                 NaN              NaN
# 51372                            NaN                 NaN              NaN
# 51379                            NaN                 NaN              NaN
#
#             CareerSatisfaction  JobSatisfaction ExCoderReturn ExCoderNotForMe  \
# Respondent
# 3                          8.0              9.0           NaN             NaN
# 15                         8.0              8.0           NaN             NaN
# 18                         9.0              8.0           NaN             NaN
# 19                         5.0              3.0           NaN             NaN
# 23                         8.0              9.0           NaN             NaN
# ...                        ...              ...           ...             ...
# 51316                      6.0              7.0           NaN             NaN
# 51320                     10.0             10.0           NaN             NaN
# 51336                      8.0              9.0           NaN             NaN
# 51372                      7.0              7.0           NaN             NaN
# 51379                     10.0             10.0           NaN             NaN
#
#            ExCoderBalance ExCoder10Years ExCoderBelonged ExCoderSkills  \
# Respondent
# 3                     NaN            NaN             NaN           NaN
# 15                    NaN            NaN             NaN           NaN
# 18                    NaN            NaN             NaN           NaN
# 19                    NaN            NaN             NaN           NaN
# 23                    NaN            NaN             NaN           NaN
# ...                   ...            ...             ...           ...
# 51316                 NaN            NaN             NaN           NaN
# 51320                 NaN            NaN             NaN           NaN
# 51336                 NaN            NaN             NaN           NaN
# 51372                 NaN            NaN             NaN           NaN
# 51379                 NaN            NaN             NaN           NaN
#
#            ExCoderWillNotCode ExCoderActive                  PronounceGIF  \
# Respondent
# 3                         NaN           NaN  With a hard "g," like "gift"
# 15                        NaN           NaN  With a hard "g," like "gift"
# 18                        NaN           NaN  With a hard "g," like "gift"
# 19                        NaN           NaN  With a hard "g," like "gift"
# 23                        NaN           NaN  With a hard "g," like "gift"
# ...                       ...           ...                           ...
# 51316                     NaN           NaN  With a hard "g," like "gift"
# 51320                     NaN           NaN                Some other way
# 51336                     NaN           NaN  With a hard "g," like "gift"
# 51372                     NaN           NaN  With a hard "g," like "gift"
# 51379                     NaN           NaN  With a hard "g," like "gift"
#
#             ProblemSolving  BuildingThings LearningNewTech      BoringDetails  \
# Respondent
# 3           Strongly agree  Strongly agree  Strongly agree     Somewhat agree
# 15          Strongly agree  Strongly agree           Agree           Disagree
# 18          Strongly agree  Strongly agree  Strongly agree  Strongly disagree
# 19          Strongly agree  Strongly agree  Strongly agree           Disagree
# 23                     NaN             NaN             NaN                NaN
# ...                    ...             ...             ...                ...
# 51316       Strongly agree  Strongly agree  Somewhat agree           Disagree
# 51320       Strongly agree           Agree           Agree           Disagree
# 51336       Strongly agree  Strongly agree  Strongly agree           Disagree
# 51372                Agree           Agree           Agree     Somewhat agree
# 51379       Strongly agree  Strongly agree  Somewhat agree  Strongly disagree
#
#                JobSecurity DiversityImportant      AnnoyingUI  \
# Respondent
# 3                    Agree     Strongly agree           Agree
# 15          Somewhat agree     Somewhat agree  Strongly agree
# 18                   Agree              Agree           Agree
# 19          Strongly agree              Agree  Somewhat agree
# 23                     NaN                NaN             NaN
# ...                    ...                ...             ...
# 51316                Agree              Agree  Strongly agree
# 51320                Agree              Agree  Strongly agree
# 51336                Agree     Somewhat agree  Strongly agree
# 51372                Agree              Agree           Agree
# 51379                Agree           Disagree  Strongly agree
#
#             FriendsDevelopers      RightWrongWay UnderstandComputers  \
# Respondent
# 3              Somewhat agree           Disagree            Disagree
# 15             Somewhat agree     Somewhat agree            Disagree
# 18                   Disagree           Disagree      Strongly agree
# 19                      Agree           Disagree            Disagree
# 23                        NaN                NaN                 NaN
# ...                       ...                ...                 ...
# 51316          Somewhat agree     Somewhat agree            Disagree
# 51320                   Agree  Strongly disagree      Somewhat agree
# 51336       Strongly disagree     Somewhat agree            Disagree
# 51372                   Agree              Agree            Disagree
# 51379       Strongly disagree  Strongly disagree      Somewhat agree
#
#                SeriousWork InvestTimeTools        WorkPayCare  \
# Respondent
# 3                    Agree  Somewhat agree           Disagree
# 15                   Agree           Agree           Disagree
# 18                   Agree           Agree  Strongly disagree
# 19                   Agree           Agree     Somewhat agree
# 23                     NaN             NaN                NaN
# ...                    ...             ...                ...
# 51316                Agree  Somewhat agree           Disagree
# 51320       Somewhat agree  Strongly agree           Disagree
# 51336                Agree  Somewhat agree     Somewhat agree
# 51372                Agree  Somewhat agree           Disagree
# 51379                Agree  Strongly agree  Strongly disagree
#
#            KinshipDevelopers  ... EquipmentSatisfiedStorage  \
# Respondent                    ...
# 3             Somewhat agree  ...                 Satisfied
# 15            Somewhat agree  ...        Somewhat satisfied
# 18                     Agree  ...        Somewhat satisfied
# 19            Strongly agree  ...                       NaN
# 23                       NaN  ...            Very satisfied
# ...                      ...  ...                       ...
# 51316         Strongly agree  ...                 Satisfied
# 51320               Disagree  ...                 Satisfied
# 51336         Somewhat agree  ...                 Satisfied
# 51372         Somewhat agree  ...        Somewhat satisfied
# 51379         Strongly agree  ...            Very satisfied
#
#            EquipmentSatisfiedRW     InfluenceInternet  \
# Respondent
# 3            Somewhat satisfied        Very satisfied
# 15                    Satisfied    Somewhat satisfied
# 18           Not very satisfied    Somewhat satisfied
# 19                          NaN                   NaN
# 23               Very satisfied        Very satisfied
# ...                         ...                   ...
# 51316            Very satisfied        Very satisfied
# 51320        Somewhat satisfied        Very satisfied
# 51336                 Satisfied             Satisfied
# 51372        Somewhat satisfied    Somewhat satisfied
# 51379            Very satisfied  Not at all satisfied
#
#                      InfluenceWorkstation              InfluenceHardware  \
# Respondent
# 3                      A lot of influence                 Some influence
# 15                     A lot of influence             Not much influence
# 18                     A lot of influence                 Some influence
# 19                                    NaN                            NaN
# 23                     A lot of influence                 Some influence
# ...                                   ...                            ...
# 51316                  Not much influence            No influence at all
# 51320                      Some influence            No influence at all
# 51336                      Some influence             Not much influence
# 51372                      Some influence             Not much influence
# 51379       I am the final decision maker  I am the final decision maker
#
#                          InfluenceServers             InfluenceTechStack  \
# Respondent
# 3                          Some influence                 Some influence
# 15                     Not much influence            No influence at all
# 18                     Not much influence                 Some influence
# 19                                    NaN                            NaN
# 23                    No influence at all            No influence at all
# ...                                   ...                            ...
# 51316                      Some influence            No influence at all
# 51320                 No influence at all            No influence at all
# 51336                  Not much influence             Not much influence
# 51372                      Some influence             A lot of influence
# 51379       I am the final decision maker  I am the final decision maker
#
#                         InfluenceDeptTech    InfluenceVizTools  \
# Respondent
# 3                      A lot of influence       Some influence
# 15                     Not much influence  No influence at all
# 18                     A lot of influence   Not much influence
# 19                                    NaN                  NaN
# 23                     A lot of influence  No influence at all
# ...                                   ...                  ...
# 51316                      Some influence   Not much influence
# 51320                  Not much influence  No influence at all
# 51336                      Some influence   Not much influence
# 51372                      Some influence   Not much influence
# 51379       I am the final decision maker  No influence at all
#
#                         InfluenceDatabase                 InfluenceCloud  \
# Respondent
# 3                          Some influence                 Some influence
# 15                    No influence at all            No influence at all
# 18                         Some influence             A lot of influence
# 19                                    NaN                            NaN
# 23                    No influence at all            No influence at all
# ...                                   ...                            ...
# 51316                 No influence at all             Not much influence
# 51320                 No influence at all            No influence at all
# 51336                      Some influence             Not much influence
# 51372                      Some influence                 Some influence
# 51379       I am the final decision maker  I am the final decision maker
#
#                      InfluenceConsultants InfluenceRecruitment  \
# Respondent
# 3                          Some influence       Some influence
# 15                     Not much influence  No influence at all
# 18                     Not much influence   Not much influence
# 19                                    NaN                  NaN
# 23                    No influence at all  No influence at all
# ...                                   ...                  ...
# 51316                 No influence at all  No influence at all
# 51320                 No influence at all  No influence at all
# 51336                      Some influence   Not much influence
# 51372                 No influence at all  No influence at all
# 51379       I am the final decision maker       Some influence
#
#                    InfluenceCommunication  \
# Respondent
# 3                          Some influence
# 15                    No influence at all
# 18                     A lot of influence
# 19                                    NaN
# 23                    No influence at all
# ...                                   ...
# 51316                 No influence at all
# 51320                 No influence at all
# 51336                  Not much influence
# 51372                      Some influence
# 51379       I am the final decision maker
#
#                                        StackOverflowDescribes  \
# Respondent
# 3           I have created a CV or Developer Story on Stac...
# 15          I have created a CV or Developer Story on Stac...
# 18          I have created a CV or Developer Story on Stac...
# 19                                                        NaN
# 23          I have a login for Stack Overflow, but haven't...
# ...                                                       ...
# 51316       I have created a CV or Developer Story on Stac...
# 51320       I've visited Stack Overflow, but haven't logge...
# 51336       I have a login for Stack Overflow, but haven't...
# 51372       I have a login for Stack Overflow, but haven't...
# 51379       I have created a CV or Developer Story on Stac...
#
#            StackOverflowSatisfaction           StackOverflowDevices  \
# Respondent
# 3                                8.0  Desktop; iOS browser; iOS app
# 15                               8.0  Desktop; iOS browser; iOS app
# 18                               8.0       Desktop; Android browser
# 19                               NaN                            NaN
# 23                               8.0           Desktop; iOS browser
# ...                              ...                            ...
# 51316                            7.0  Desktop; iOS browser; iOS app
# 51320                            8.0           Desktop; iOS browser
# 51336                            9.0       Desktop; Android browser
# 51372                            8.0                        Desktop
# 51379                           10.0           Desktop; iOS browser
#
#            StackOverflowFoundAnswer  StackOverflowCopiedCode  \
# Respondent
# 3                     Once or twice      Haven't done at all
# 15                    Several times            Once or twice
# 18          At least once each week  At least once each week
# 19                              NaN                      NaN
# 23           At least once each day            Once or twice
# ...                             ...                      ...
# 51316                 Several times      Haven't done at all
# 51320       At least once each week            Once or twice
# 51336       At least once each week            Several times
# 51372        At least once each day      Haven't done at all
# 51379        At least once each day            Several times
#
#            StackOverflowJobListing StackOverflowCompanyPage  \
# Respondent
# 3              Haven't done at all      Haven't done at all
# 15                   Several times            Several times
# 18                   Once or twice      Haven't done at all
# 19                             NaN                      NaN
# 23             Haven't done at all      Haven't done at all
# ...                            ...                      ...
# 51316          Haven't done at all      Haven't done at all
# 51320          Haven't done at all      Haven't done at all
# 51336                Several times            Once or twice
# 51372                Several times  At least once each week
# 51379          Haven't done at all            Several times
#
#              StackOverflowJobSearch StackOverflowNewQuestion  \
# Respondent
# 3               Haven't done at all      Haven't done at all
# 15                    Several times            Once or twice
# 18              Haven't done at all  At least once each week
# 19                              NaN                      NaN
# 23              Haven't done at all            Once or twice
# ...                             ...                      ...
# 51316           Haven't done at all      Haven't done at all
# 51320           Haven't done at all      Haven't done at all
# 51336           Haven't done at all            Once or twice
# 51372       At least once each week      Haven't done at all
# 51379           Haven't done at all   At least once each day
#
#                 StackOverflowAnswer   StackOverflowMetaChat  \
# Respondent
# 3            At least once each day  At least once each day
# 15           At least once each day           Several times
# 18          At least once each week     Haven't done at all
# 19                              NaN                     NaN
# 23              Haven't done at all     Haven't done at all
# ...                             ...                     ...
# 51316                 Once or twice     Haven't done at all
# 51320           Haven't done at all     Haven't done at all
# 51336           Haven't done at all     Haven't done at all
# 51372           Haven't done at all     Haven't done at all
# 51379        At least once each day           Several times
#
#            StackOverflowAdsRelevant StackOverflowAdsDistracting  \
# Respondent
# 3                          Disagree                    Disagree
# 15                         Disagree                    Disagree
# 18                   Somewhat agree                    Disagree
# 19                              NaN                         NaN
# 23                   Somewhat agree                    Disagree
# ...                             ...                         ...
# 51316                      Disagree                    Disagree
# 51320                           NaN                         NaN
# 51336                Somewhat agree                    Disagree
# 51372                         Agree           Strongly disagree
# 51379             Strongly disagree           Strongly disagree
#
#            StackOverflowModeration StackOverflowCommunity  \
# Respondent
# 3                Strongly disagree         Strongly agree
# 15                        Disagree                  Agree
# 18                        Disagree                  Agree
# 19                             NaN                    NaN
# 23                        Disagree                  Agree
# ...                            ...                    ...
# 51316                     Disagree         Somewhat agree
# 51320                        Agree      Strongly disagree
# 51336                     Disagree               Disagree
# 51372                     Disagree      Strongly disagree
# 51379            Strongly disagree         Strongly agree
#
#            StackOverflowHelpful StackOverflowBetter StackOverflowWhatDo  \
# Respondent
# 3                         Agree               Agree               Agree
# 15                        Agree      Strongly agree               Agree
# 18               Strongly agree      Strongly agree      Strongly agree
# 19                          NaN                 NaN                 NaN
# 23               Strongly agree      Strongly agree               Agree
# ...                         ...                 ...                 ...
# 51316                     Agree   Strongly disagree      Somewhat agree
# 51320                     Agree               Agree               Agree
# 51336                     Agree               Agree      Strongly agree
# 51372                     Agree               Agree      Strongly agree
# 51379            Strongly agree      Strongly agree   Strongly disagree
#
#            StackOverflowMakeMoney Gender    HighestEducationParents  \
# Respondent
# 3                        Disagree   Male      A professional degree
# 15                       Disagree   Male                High school
# 18                       Disagree   Male          A master's degree
# 19                            NaN    NaN                        NaN
# 23                 Somewhat agree   Male        A bachelor's degree
# ...                           ...    ...                        ...
# 51316                    Disagree   Male          A doctoral degree
# 51320                    Disagree   Male          A master's degree
# 51336                    Disagree   Male  Primary/elementary school
# 51372                    Disagree   Male        A bachelor's degree
# 51379           Strongly disagree   Male          A doctoral degree
#
#                                                          Race      SurveyLong  \
# Respondent
# 3                                White or of European descent  Somewhat agree
# 15                               White or of European descent  Somewhat agree
# 18          Native American, Pacific Islander, or Indigeno...        Disagree
# 19                                                        NaN             NaN
# 23                               White or of European descent  Strongly agree
# ...                                                       ...             ...
# 51316                            White or of European descent        Disagree
# 51320                            White or of European descent  Somewhat agree
# 51336                            White or of European descent  Somewhat agree
# 51372                            White or of European descent        Disagree
# 51379                                                     NaN  Somewhat agree
#
#            QuestionsInteresting QuestionsConfusing InterestedAnswers  \
# Respondent
# 3                         Agree           Disagree             Agree
# 15                        Agree           Disagree             Agree
# 18                        Agree           Disagree             Agree
# 19                          NaN                NaN               NaN
# 23               Somewhat agree     Somewhat agree             Agree
# ...                         ...                ...               ...
# 51316                     Agree           Disagree    Strongly agree
# 51320                     Agree           Disagree             Agree
# 51336                     Agree  Strongly disagree    Strongly agree
# 51372                     Agree  Strongly disagree             Agree
# 51379            Strongly agree  Strongly disagree    Strongly agree
#
#                    Salary ExpectedSalary
# Respondent
# 3           113750.000000            NaN
# 15          100000.000000            NaN
# 18          130000.000000            NaN
# 19           82500.000000            NaN
# 23          100764.000000            NaN
# ...                   ...            ...
# 51316       140000.000000            NaN
# 51320       105000.000000            NaN
# 51336        88750.000000            NaN
# 51372        74193.548387            NaN
# 51379       107526.881720            NaN
#
# [3942 rows x 153 columns]

# %%
df.loc[high_salary, ['Country', 'Salary']]
# Out:
#                    Country         Salary
# Respondent
# 3           United Kingdom  113750.000000
# 15          United Kingdom  100000.000000
# 18           United States  130000.000000
# 19           United States   82500.000000
# 23                  Israel  100764.000000
# ...                    ...            ...
# 51316        United States  140000.000000
# 51320        United States  105000.000000
# 51336       United Kingdom   88750.000000
# 51372          Netherlands   74193.548387
# 51379               Cyprus  107526.881720
#
# [3942 rows x 2 columns]

# %%
countries = ['United Kingdom', 'United States', 'Israel', 'India', 'Germany', 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# Respondent
# 1         United States
# 2        United Kingdom
# 3        United Kingdom
# 4         United States
# 7         United States
#               ...
# 51385     United States
# 51386    United Kingdom
# 51388     United States
# 51390            Canada
# 51391     United States
# Name: Country, Length: 27998, dtype: object
