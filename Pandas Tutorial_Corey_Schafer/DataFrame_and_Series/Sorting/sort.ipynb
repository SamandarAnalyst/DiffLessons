# %%
people = {
    "first" : ['Corey', 'Jane', 'John','Adam'],
    "last" : ['Schafer', 'Doe', 'Doe', 'Doe'],
    "email" : ['CoreyMSchafer@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com', 'A@gmail.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com
# 3   Adam      Doe              A@gmail.com

# %%
df.sort_values(by='last')
# Out:
#    first     last                    email
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com
# 3   Adam      Doe              A@gmail.com
# 0  Corey  Schafer  CoreyMSchafer@gmail.com

# %%
df.sort_values(by='last', ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com
# 3   Adam      Doe              A@gmail.com

# %%
df.sort_values(by=['last', 'first'], ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 2   John      Doe        JohnDoe@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 3   Adam      Doe              A@gmail.com

# %%
df.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 3   Adam      Doe              A@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %%
df.sort_index()
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com
# 3   Adam      Doe              A@gmail.com

# %%
df['last'].sort_values()
# Out:
# 3        Doe
# 1        Doe
# 2        Doe
# 0    Schafer
# Name: last, dtype: object

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                  Professional  \
# Respondent
# 1                                                     Student
# 2                                                     Student
# 3                                      Professional developer
# 4           Professional non-developer who sometimes write...
# 5                                      Professional developer
#
#                          ProgramHobby         Country      University  \
# Respondent
# 1                           Yes, both   United States              No
# 2                           Yes, both  United Kingdom  Yes, full-time
# 3                           Yes, both  United Kingdom              No
# 4                           Yes, both   United States              No
# 5           Yes, I program as a hobby     Switzerland              No
#
#                                   EmploymentStatus  \
# Respondent
# 1           Not employed, and not looking for work
# 2                               Employed part-time
# 3                               Employed full-time
# 4                               Employed full-time
# 5                               Employed full-time
#
#                                               FormalEducation  \
# Respondent
# 1                                            Secondary school
# 2           Some college/university study without earning ...
# 3                                           Bachelor's degree
# 4                                             Doctoral degree
# 5                                             Master's degree
#
#                                            MajorUndergrad  \
# Respondent
# 1                                                     NaN
# 2                Computer science or software engineering
# 3                Computer science or software engineering
# 4           A non-computer-focused engineering discipline
# 5                Computer science or software engineering
#
#                                                    HomeRemote  \
# Respondent
# 1                                                         NaN
# 2                       More than half, but not all, the time
# 3           Less than half the time, but at least one day ...
# 4           Less than half the time, but at least one day ...
# 5                                                       Never
#
#                          CompanySize  \
# Respondent
# 1                                NaN
# 2                 20 to 99 employees
# 3           10,000 or more employees
# 4           10,000 or more employees
# 5                 10 to 19 employees
#
#                                                   CompanyType  \
# Respondent
# 1                                                         NaN
# 2           Privately-held limited company, not in startup...
# 3                                 Publicly-traded corporation
# 4           Non-profit/non-governmental organization or pr...
# 5           Privately-held limited company, not in startup...
#
#                 YearsProgram     YearsCodedJob YearsCodedJobPast  \
# Respondent
# 1               2 to 3 years               NaN               NaN
# 2              9 to 10 years               NaN               NaN
# 3           20 or more years  20 or more years               NaN
# 4             14 to 15 years     9 to 10 years               NaN
# 5           20 or more years    10 to 11 years               NaN
#
#                                                 DeveloperType  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                       Other
# 4                                                         NaN
# 5           Mobile developer; Graphics programming; Deskto...
#
#            WebDeveloperType MobileDeveloperType NonDeveloperType  \
# Respondent
# 1                       NaN                 NaN              NaN
# 2                       NaN                 NaN              NaN
# 3                       NaN                 NaN              NaN
# 4                       NaN                 NaN   Data scientist
# 5                       NaN                 NaN              NaN
#
#             CareerSatisfaction  JobSatisfaction ExCoderReturn ExCoderNotForMe  \
# Respondent
# 1                          NaN              NaN           NaN             NaN
# 2                          NaN              NaN           NaN             NaN
# 3                          8.0              9.0           NaN             NaN
# 4                          6.0              3.0           NaN             NaN
# 5                          6.0              8.0           NaN             NaN
#
#            ExCoderBalance ExCoder10Years ExCoderBelonged ExCoderSkills  \
# Respondent
# 1                     NaN            NaN             NaN           NaN
# 2                     NaN            NaN             NaN           NaN
# 3                     NaN            NaN             NaN           NaN
# 4                     NaN            NaN             NaN           NaN
# 5                     NaN            NaN             NaN           NaN
#
#            ExCoderWillNotCode ExCoderActive                  PronounceGIF  \
# Respondent
# 1                         NaN           NaN  With a soft "g," like "jiff"
# 2                         NaN           NaN  With a hard "g," like "gift"
# 3                         NaN           NaN  With a hard "g," like "gift"
# 4                         NaN           NaN  With a soft "g," like "jiff"
# 5                         NaN           NaN  With a soft "g," like "jiff"
#
#             ProblemSolving  BuildingThings LearningNewTech   BoringDetails  \
# Respondent
# 1           Strongly agree  Strongly agree           Agree        Disagree
# 2                      NaN             NaN             NaN             NaN
# 3           Strongly agree  Strongly agree  Strongly agree  Somewhat agree
# 4           Strongly agree  Strongly agree  Strongly agree        Disagree
# 5                      NaN             NaN             NaN             NaN
#
#                JobSecurity DiversityImportant AnnoyingUI FriendsDevelopers  \
# Respondent
# 1           Strongly agree              Agree      Agree          Disagree
# 2                      NaN                NaN        NaN               NaN
# 3                    Agree     Strongly agree      Agree    Somewhat agree
# 4           Somewhat agree              Agree      Agree             Agree
# 5                      NaN                NaN        NaN               NaN
#
#              RightWrongWay UnderstandComputers     SeriousWork  \
# Respondent
# 1           Somewhat agree            Disagree  Strongly agree
# 2                      NaN                 NaN             NaN
# 3                 Disagree            Disagree           Agree
# 4           Somewhat agree   Strongly disagree  Strongly agree
# 5                      NaN                 NaN             NaN
#
#            InvestTimeTools        WorkPayCare KinshipDevelopers  ...  \
# Respondent                                                       ...
# 1           Strongly agree  Strongly disagree             Agree  ...
# 2                      NaN                NaN               NaN  ...
# 3           Somewhat agree           Disagree    Somewhat agree  ...
# 4                    Agree           Disagree    Strongly agree  ...
# 5                      NaN                NaN               NaN  ...
#
#            EquipmentSatisfiedStorage EquipmentSatisfiedRW   InfluenceInternet  \
# Respondent
# 1                     Very satisfied            Satisfied  Not very satisfied
# 2                          Satisfied   Somewhat satisfied           Satisfied
# 3                          Satisfied   Somewhat satisfied      Very satisfied
# 4                                NaN                  NaN                 NaN
# 5                          Satisfied            Satisfied           Satisfied
#
#            InfluenceWorkstation    InfluenceHardware     InfluenceServers  \
# Respondent
# 1                           NaN                  NaN                  NaN
# 2           No influence at all  No influence at all  No influence at all
# 3            A lot of influence       Some influence       Some influence
# 4                           NaN                  NaN                  NaN
# 5                           NaN                  NaN                  NaN
#
#              InfluenceTechStack    InfluenceDeptTech    InfluenceVizTools  \
# Respondent
# 1                           NaN                  NaN                  NaN
# 2           No influence at all  No influence at all  No influence at all
# 3                Some influence   A lot of influence       Some influence
# 4                           NaN                  NaN                  NaN
# 5                           NaN                  NaN                  NaN
#
#               InfluenceDatabase       InfluenceCloud InfluenceConsultants  \
# Respondent
# 1                           NaN                  NaN                  NaN
# 2           No influence at all  No influence at all  No influence at all
# 3                Some influence       Some influence       Some influence
# 4                           NaN                  NaN                  NaN
# 5                           NaN                  NaN                  NaN
#
#            InfluenceRecruitment InfluenceCommunication  \
# Respondent
# 1                           NaN                    NaN
# 2           No influence at all    No influence at all
# 3                Some influence         Some influence
# 4                           NaN                    NaN
# 5                           NaN                    NaN
#
#                                        StackOverflowDescribes  \
# Respondent
# 1           I have created a CV or Developer Story on Stac...
# 2           I have created a CV or Developer Story on Stac...
# 3           I have created a CV or Developer Story on Stac...
# 4           I have created a CV or Developer Story on Stac...
# 5                                                         NaN
#
#            StackOverflowSatisfaction  \
# Respondent
# 1                                9.0
# 2                                8.0
# 3                                8.0
# 4                               10.0
# 5                                NaN
#
#                                          StackOverflowDevices  \
# Respondent
# 1                                            Desktop; iOS app
# 2           Desktop; iOS browser; iOS app; Android browser...
# 3                               Desktop; iOS browser; iOS app
# 4                               Desktop; iOS browser; iOS app
# 5                                                         NaN
#
#            StackOverflowFoundAnswer StackOverflowCopiedCode  \
# Respondent
# 1           At least once each week     Haven't done at all
# 2                     Several times           Several times
# 3                     Once or twice     Haven't done at all
# 4           At least once each week           Several times
# 5                               NaN                     NaN
#
#             StackOverflowJobListing StackOverflowCompanyPage  \
# Respondent
# 1                     Once or twice      Haven't done at all
# 2                     Once or twice            Once or twice
# 3               Haven't done at all      Haven't done at all
# 4           At least once each week            Several times
# 5                               NaN                      NaN
#
#              StackOverflowJobSearch StackOverflowNewQuestion  \
# Respondent
# 1               Haven't done at all            Several times
# 2                     Once or twice      Haven't done at all
# 3               Haven't done at all      Haven't done at all
# 4           At least once each week            Several times
# 5                               NaN                      NaN
#
#                StackOverflowAnswer    StackOverflowMetaChat  \
# Respondent
# 1                    Several times            Once or twice
# 2                    Several times  At least once each week
# 3           At least once each day   At least once each day
# 4           At least once each day   At least once each day
# 5                              NaN                      NaN
#
#            StackOverflowAdsRelevant StackOverflowAdsDistracting  \
# Respondent
# 1                    Somewhat agree           Strongly disagree
# 2                          Disagree           Strongly disagree
# 3                          Disagree                    Disagree
# 4                             Agree           Strongly disagree
# 5                               NaN                         NaN
#
#            StackOverflowModeration StackOverflowCommunity  \
# Respondent
# 1                Strongly disagree         Strongly agree
# 2                Strongly disagree         Strongly agree
# 3                Strongly disagree         Strongly agree
# 4                Strongly disagree         Strongly agree
# 5                              NaN                    NaN
#
#            StackOverflowHelpful StackOverflowBetter StackOverflowWhatDo  \
# Respondent
# 1                         Agree      Strongly agree      Strongly agree
# 2                         Agree      Strongly agree      Strongly agree
# 3                         Agree               Agree               Agree
# 4                Strongly agree               Agree      Strongly agree
# 5                           NaN                 NaN                 NaN
#
#            StackOverflowMakeMoney Gender HighestEducationParents  \
# Respondent
# 1               Strongly disagree   Male             High school
# 2               Strongly disagree   Male       A master's degree
# 3                        Disagree   Male   A professional degree
# 4                        Disagree   Male       A doctoral degree
# 5                             NaN    NaN                     NaN
#
#                                     Race         SurveyLong  \
# Respondent
# 1           White or of European descent  Strongly disagree
# 2           White or of European descent     Somewhat agree
# 3           White or of European descent     Somewhat agree
# 4           White or of European descent              Agree
# 5                                    NaN                NaN
#
#            QuestionsInteresting QuestionsConfusing InterestedAnswers  \
# Respondent
# 1                Strongly agree           Disagree    Strongly agree
# 2                Somewhat agree           Disagree    Strongly agree
# 3                         Agree           Disagree             Agree
# 4                         Agree     Somewhat agree    Strongly agree
# 5                           NaN                NaN               NaN
#
#               Salary ExpectedSalary
# Respondent
# 1                NaN            NaN
# 2                NaN        37500.0
# 3           113750.0            NaN
# 4                NaN            NaN
# 5                NaN            NaN
#
# [5 rows x 153 columns]

# %%
df.sort_values(by=['Country', 'Salary'], ascending=[True, False] ,inplace=True)

# %%
df['Country'].head(10)
# Out:
# Respondent
# 51257    Afghanistan
# 15032    Afghanistan
# 3241     Afghanistan
# 11990    Afghanistan
# 49509    Afghanistan
# 34241    Afghanistan
# 14944    Afghanistan
# 23524    Afghanistan
# 10277    Afghanistan
# 26358    Afghanistan
# Name: Country, dtype: object

# %%
df[['Country', 'Salary']].head(50)
# Out:
#                 Country        Salary
# Respondent
# 51257       Afghanistan  75757.575758
# 15032       Afghanistan  16143.497758
# 3241        Afghanistan   1500.000000
# 11990       Afghanistan           NaN
# 49509       Afghanistan           NaN
# 34241       Afghanistan           NaN
# 14944       Afghanistan           NaN
# 23524       Afghanistan           NaN
# 10277       Afghanistan           NaN
# 26358       Afghanistan           NaN
# 38393       Afghanistan           NaN
# 24002       Afghanistan           NaN
# 25822       Afghanistan           NaN
# 26451       Afghanistan           NaN
# 48730       Afghanistan           NaN
# 35750       Afghanistan           NaN
# 29312       Afghanistan           NaN
# 30150       Afghanistan           NaN
# 49962       Afghanistan           NaN
# 36979       Afghanistan           NaN
# 27466       Afghanistan           NaN
# 46747       Afghanistan           NaN
# 16743       Afghanistan           NaN
# 44609       Afghanistan           NaN
# 43099       Afghanistan           NaN
# 25319       Afghanistan           NaN
# 20774       Afghanistan           NaN
# 11078       Afghanistan           NaN
# 27151       Afghanistan           NaN
# 21354       Afghanistan           NaN
# 49036       Afghanistan           NaN
# 5771        Afghanistan           NaN
# 30469       Afghanistan           NaN
# 33345       Afghanistan           NaN
# 34532       Afghanistan           NaN
# 49676       Afghanistan           NaN
# 50252       Afghanistan           NaN
# 40257       Afghanistan           NaN
# 32384       Afghanistan           NaN
# 46442       Afghanistan           NaN
# 48105       Afghanistan           NaN
# 25426       Afghanistan           NaN
# 49130       Afghanistan           NaN
# 8567        Afghanistan           NaN
# 20703       Afghanistan           NaN
# 13861       Afghanistan           NaN
# 16518       Afghanistan           NaN
# 50599       Afghanistan           NaN
# 45373       Afghanistan           NaN
# 50565       Afghanistan           NaN

# %%
df['Salary'].nlargest(10)
# Out:
# Respondent
# 31601    197000.0
# 1697     195000.0
# 27944    195000.0
# 18238    195000.0
# 6744     195000.0
# 41399    195000.0
# 32623    194000.0
# 6718     193750.0
# 30551    193000.0
# 2371     192000.0
# Name: Salary, dtype: float64

# %%
df.nlargest(10, 'Salary')
# Out:
#                       Professional               ProgramHobby         Country  \
# Respondent
# 31601       Professional developer                         No   United States
# 1697        Professional developer                  Yes, both   United States
# 27944       Professional developer                         No   United States
# 18238       Professional developer                  Yes, both   United States
# 6744        Professional developer  Yes, I program as a hobby   United States
# 41399       Professional developer                  Yes, both   United States
# 32623       Professional developer                  Yes, both   United States
# 6718        Professional developer                  Yes, both  United Kingdom
# 30551       Professional developer                         No     Switzerland
# 2371        Professional developer  Yes, I program as a hobby   United States
#
#                 University    EmploymentStatus    FormalEducation  \
# Respondent
# 31601       Yes, part-time  Employed full-time    Doctoral degree
# 1697                    No  Employed full-time  Bachelor's degree
# 27944                   No  Employed full-time  Bachelor's degree
# 18238                   No  Employed full-time  Bachelor's degree
# 6744                    No  Employed full-time  Bachelor's degree
# 41399                   No  Employed full-time  Bachelor's degree
# 32623                   No  Employed full-time    Master's degree
# 6718                    No  Employed full-time    Doctoral degree
# 30551                   No  Employed full-time    Master's degree
# 2371                    No  Employed full-time    Master's degree
#
#                                                MajorUndergrad  \
# Respondent
# 31601                Computer science or software engineering
# 1697                 Computer science or software engineering
# 27944                Computer science or software engineering
# 18238                Computer science or software engineering
# 6744                 Computer science or software engineering
# 41399                Computer science or software engineering
# 32623                Computer science or software engineering
# 6718                                Mathematics or statistics
# 30551                Computer science or software engineering
# 2371        Computer engineering or electrical/electronics...
#
#                                                    HomeRemote  \
# Respondent
# 31601                                                   Never
# 1697        All or almost all the time (I'm full-time remote)
# 27944       Less than half the time, but at least one day ...
# 18238       All or almost all the time (I'm full-time remote)
# 6744                                                    Never
# 41399       Less than half the time, but at least one day ...
# 32623       Less than half the time, but at least one day ...
# 6718                                    A few days each month
# 30551                                                   Never
# 2371                                    A few days each month
#
#                          CompanySize  \
# Respondent
# 31601           500 to 999 employees
# 1697        10,000 or more employees
# 27944       1,000 to 4,999 employees
# 18238           100 to 499 employees
# 6744        10,000 or more employees
# 41399             10 to 19 employees
# 32623             20 to 99 employees
# 6718        10,000 or more employees
# 30551       10,000 or more employees
# 2371        1,000 to 4,999 employees
#
#                                                   CompanyType  \
# Respondent
# 31601       Privately-held limited company, not in startup...
# 1697                              Publicly-traded corporation
# 27944                                  Venture-funded startup
# 18238       Privately-held limited company, not in startup...
# 6744                              Publicly-traded corporation
# 41399                                    Pre-series A startup
# 32623       Privately-held limited company, not in startup...
# 6718                              Publicly-traded corporation
# 30551                             Publicly-traded corporation
# 2371        Privately-held limited company, not in startup...
#
#                 YearsProgram     YearsCodedJob YearsCodedJobPast  \
# Respondent
# 31601       20 or more years    14 to 15 years               NaN
# 1697        20 or more years  20 or more years               NaN
# 27944       20 or more years    12 to 13 years               NaN
# 18238       20 or more years    10 to 11 years               NaN
# 6744        20 or more years  20 or more years               NaN
# 41399       20 or more years    16 to 17 years               NaN
# 32623       20 or more years  20 or more years               NaN
# 6718        20 or more years    17 to 18 years               NaN
# 30551         18 to 19 years     9 to 10 years               NaN
# 2371        20 or more years    14 to 15 years               NaN
#
#                                                 DeveloperType  \
# Respondent
# 31601       Mobile developer; Machine learning specialist;...
# 1697        Web developer; Embedded applications/devices d...
# 27944                                           Web developer
# 18238                                           Web developer
# 6744                                            Web developer
# 41399                         Web developer; Mobile developer
# 32623                          Desktop applications developer
# 6718        Developer with a statistics or mathematics bac...
# 30551       Developer with a statistics or mathematics bac...
# 2371        Embedded applications/devices developer; Deskt...
#
#                     WebDeveloperType MobileDeveloperType NonDeveloperType  \
# Respondent
# 31601                            NaN                 NaN              NaN
# 1697                             NaN                 NaN              NaN
# 27944       Full stack Web developer                 NaN              NaN
# 18238       Full stack Web developer                 NaN              NaN
# 6744        Full stack Web developer                 NaN              NaN
# 41399                            NaN                 NaN              NaN
# 32623                            NaN                 NaN              NaN
# 6718                             NaN                 NaN              NaN
# 30551                            NaN                 NaN              NaN
# 2371                             NaN                 NaN              NaN
#
#             CareerSatisfaction  JobSatisfaction ExCoderReturn ExCoderNotForMe  \
# Respondent
# 31601                      7.0              5.0           NaN             NaN
# 1697                       8.0              9.0           NaN             NaN
# 27944                      7.0              7.0           NaN             NaN
# 18238                      8.0              9.0           NaN             NaN
# 6744                       6.0              6.0           NaN             NaN
# 41399                      9.0              9.0           NaN             NaN
# 32623                     10.0             10.0           NaN             NaN
# 6718                       7.0              6.0           NaN             NaN
# 30551                      7.0              7.0           NaN             NaN
# 2371                       8.0              8.0           NaN             NaN
#
#            ExCoderBalance ExCoder10Years ExCoderBelonged ExCoderSkills  \
# Respondent
# 31601                 NaN            NaN             NaN           NaN
# 1697                  NaN            NaN             NaN           NaN
# 27944                 NaN            NaN             NaN           NaN
# 18238                 NaN            NaN             NaN           NaN
# 6744                  NaN            NaN             NaN           NaN
# 41399                 NaN            NaN             NaN           NaN
# 32623                 NaN            NaN             NaN           NaN
# 6718                  NaN            NaN             NaN           NaN
# 30551                 NaN            NaN             NaN           NaN
# 2371                  NaN            NaN             NaN           NaN
#
#            ExCoderWillNotCode ExCoderActive                  PronounceGIF  \
# Respondent
# 31601                     NaN           NaN  With a soft "g," like "jiff"
# 1697                      NaN           NaN  With a hard "g," like "gift"
# 27944                     NaN           NaN  With a soft "g," like "jiff"
# 18238                     NaN           NaN  With a hard "g," like "gift"
# 6744                      NaN           NaN  With a hard "g," like "gift"
# 41399                     NaN           NaN  With a hard "g," like "gift"
# 32623                     NaN           NaN  With a soft "g," like "jiff"
# 6718                      NaN           NaN  With a soft "g," like "jiff"
# 30551                     NaN           NaN  With a hard "g," like "gift"
# 2371                      NaN           NaN  With a soft "g," like "jiff"
#
#             ProblemSolving  BuildingThings LearningNewTech   BoringDetails  \
# Respondent
# 31601                  NaN             NaN             NaN             NaN
# 1697        Strongly agree  Strongly agree  Strongly agree        Disagree
# 27944                  NaN             NaN             NaN             NaN
# 18238       Strongly agree  Strongly agree           Agree        Disagree
# 6744                 Agree           Agree           Agree        Disagree
# 41399       Strongly agree  Strongly agree  Strongly agree        Disagree
# 32623                  NaN             NaN             NaN             NaN
# 6718                 Agree           Agree  Somewhat agree        Disagree
# 30551                Agree           Agree  Somewhat agree           Agree
# 2371                 Agree  Strongly agree  Strongly agree  Somewhat agree
#
#                JobSecurity DiversityImportant      AnnoyingUI  \
# Respondent
# 31601                  NaN                NaN             NaN
# 1697        Somewhat agree     Strongly agree  Strongly agree
# 27944                  NaN                NaN             NaN
# 18238       Somewhat agree  Strongly disagree  Somewhat agree
# 6744        Strongly agree     Strongly agree  Strongly agree
# 41399                Agree              Agree  Strongly agree
# 32623                  NaN                NaN             NaN
# 6718                 Agree     Somewhat agree  Somewhat agree
# 30551       Strongly agree     Strongly agree           Agree
# 2371        Somewhat agree              Agree           Agree
#
#            FriendsDevelopers RightWrongWay UnderstandComputers  \
# Respondent
# 31601                    NaN           NaN                 NaN
# 1697                   Agree      Disagree      Somewhat agree
# 27944                    NaN           NaN                 NaN
# 18238         Strongly agree      Disagree               Agree
# 6744          Somewhat agree      Disagree               Agree
# 41399         Somewhat agree      Disagree            Disagree
# 32623                    NaN           NaN                 NaN
# 6718                   Agree      Disagree            Disagree
# 30551         Somewhat agree      Disagree      Somewhat agree
# 2371                   Agree         Agree            Disagree
#
#                SeriousWork InvestTimeTools        WorkPayCare  \
# Respondent
# 31601                  NaN             NaN                NaN
# 1697                 Agree  Strongly agree     Somewhat agree
# 27944                  NaN             NaN                NaN
# 18238       Strongly agree           Agree  Strongly disagree
# 6744        Strongly agree           Agree              Agree
# 41399                Agree           Agree           Disagree
# 32623                  NaN             NaN                NaN
# 6718                 Agree        Disagree           Disagree
# 30551       Somewhat agree  Somewhat agree     Somewhat agree
# 2371                 Agree  Somewhat agree           Disagree
#
#            KinshipDevelopers  ... EquipmentSatisfiedStorage  \
# Respondent                    ...
# 31601                    NaN  ...                       NaN
# 1697          Somewhat agree  ...        Somewhat satisfied
# 27944                    NaN  ...      Not at all satisfied
# 18238         Strongly agree  ...                       NaN
# 6744                   Agree  ...            Very satisfied
# 41399         Strongly agree  ...            Very satisfied
# 32623                    NaN  ...            Very satisfied
# 6718                   Agree  ...      Not at all satisfied
# 30551         Somewhat agree  ...            Very satisfied
# 2371                   Agree  ...                       NaN
#
#            EquipmentSatisfiedRW   InfluenceInternet  \
# Respondent
# 31601                       NaN                 NaN
# 1697                  Satisfied  Not very satisfied
# 27944                 Satisfied      Very satisfied
# 18238                       NaN                 NaN
# 6744             Very satisfied      Very satisfied
# 41399            Very satisfied      Very satisfied
# 32623            Very satisfied           Satisfied
# 6718         Not very satisfied  Not very satisfied
# 30551                 Satisfied           Satisfied
# 2371                        NaN                 NaN
#
#                      InfluenceWorkstation              InfluenceHardware  \
# Respondent
# 31601                                 NaN                            NaN
# 1697                   Not much influence            No influence at all
# 27944                 No influence at all            No influence at all
# 18238                                 NaN                            NaN
# 6744                   A lot of influence            No influence at all
# 41399       I am the final decision maker             A lot of influence
# 32623       I am the final decision maker  I am the final decision maker
# 6718                   Not much influence            No influence at all
# 30551                  Not much influence            No influence at all
# 2371                                  NaN                            NaN
#
#                InfluenceServers   InfluenceTechStack    InfluenceDeptTech  \
# Respondent
# 31601                       NaN                  NaN                  NaN
# 1697        No influence at all  No influence at all       Some influence
# 27944       No influence at all  No influence at all  No influence at all
# 18238                       NaN                  NaN                  NaN
# 6744         A lot of influence  No influence at all   A lot of influence
# 41399        A lot of influence   A lot of influence   A lot of influence
# 32623        A lot of influence   A lot of influence   A lot of influence
# 6718         Not much influence  No influence at all       Some influence
# 30551       No influence at all  No influence at all  No influence at all
# 2371                        NaN                  NaN                  NaN
#
#               InfluenceVizTools              InfluenceDatabase  \
# Respondent
# 31601                       NaN                            NaN
# 1697        No influence at all            No influence at all
# 27944       No influence at all            No influence at all
# 18238                       NaN                            NaN
# 6744         A lot of influence             A lot of influence
# 41399        A lot of influence  I am the final decision maker
# 32623        A lot of influence             A lot of influence
# 6718        No influence at all             Not much influence
# 30551       No influence at all            No influence at all
# 2371                        NaN                            NaN
#
#                            InfluenceCloud InfluenceConsultants  \
# Respondent
# 31601                                 NaN                  NaN
# 1697                  No influence at all  No influence at all
# 27944                 No influence at all  No influence at all
# 18238                                 NaN                  NaN
# 6744                  No influence at all       Some influence
# 41399       I am the final decision maker   A lot of influence
# 32623                  A lot of influence   A lot of influence
# 6718                  No influence at all   Not much influence
# 30551                 No influence at all  No influence at all
# 2371                                  NaN                  NaN
#
#            InfluenceRecruitment InfluenceCommunication  \
# Respondent
# 31601                       NaN                    NaN
# 1697        No influence at all    No influence at all
# 27944       No influence at all    No influence at all
# 18238                       NaN                    NaN
# 6744        No influence at all     A lot of influence
# 41399        A lot of influence     A lot of influence
# 32623        A lot of influence     A lot of influence
# 6718        No influence at all    No influence at all
# 30551       No influence at all    No influence at all
# 2371                        NaN                    NaN
#
#                                        StackOverflowDescribes  \
# Respondent
# 31601       I have a login for Stack Overflow, but haven't...
# 1697        I have created a CV or Developer Story on Stac...
# 27944       I have a login for Stack Overflow, but haven't...
# 18238       I have a login for Stack Overflow, but haven't...
# 6744        I have a login for Stack Overflow, but haven't...
# 41399       I have a login for Stack Overflow, but haven't...
# 32623       I have a login for Stack Overflow, but haven't...
# 6718        I have created a CV or Developer Story on Stac...
# 30551       I've visited Stack Overflow, but haven't logge...
# 2371                                                      NaN
#
#            StackOverflowSatisfaction                   StackOverflowDevices  \
# Respondent
# 31601                            8.0  Desktop; iOS browser; Android browser
# 1697                             9.0               Desktop; Android browser
# 27944                            8.0                                Desktop
# 18238                            8.0               Desktop; Android browser
# 6744                            10.0                   Desktop; iOS browser
# 41399                           10.0                   Desktop; iOS browser
# 32623                            7.0                       Desktop; iOS app
# 6718                            10.0                                Desktop
# 30551                            9.0                                Desktop
# 2371                             NaN                                    NaN
#
#            StackOverflowFoundAnswer StackOverflowCopiedCode  \
# Respondent
# 31601       At least once each week           Once or twice
# 1697        At least once each week           Once or twice
# 27944       At least once each week           Once or twice
# 18238       At least once each week           Several times
# 6744        At least once each week           Several times
# 41399       At least once each week           Several times
# 32623                 Several times           Several times
# 6718                  Once or twice     Haven't done at all
# 30551       At least once each week     Haven't done at all
# 2371                            NaN                     NaN
#
#            StackOverflowJobListing StackOverflowCompanyPage  \
# Respondent
# 31601          Haven't done at all      Haven't done at all
# 1697           Haven't done at all            Once or twice
# 27944                Several times      Haven't done at all
# 18238          Haven't done at all      Haven't done at all
# 6744           Haven't done at all      Haven't done at all
# 41399          Haven't done at all      Haven't done at all
# 32623          Haven't done at all      Haven't done at all
# 6718                 Once or twice      Haven't done at all
# 30551          Haven't done at all      Haven't done at all
# 2371                           NaN                      NaN
#
#            StackOverflowJobSearch StackOverflowNewQuestion  \
# Respondent
# 31601         Haven't done at all            Several times
# 1697                Once or twice      Haven't done at all
# 27944               Several times            Several times
# 18238         Haven't done at all            Several times
# 6744          Haven't done at all      Haven't done at all
# 41399         Haven't done at all      Haven't done at all
# 32623         Haven't done at all            Several times
# 6718          Haven't done at all      Haven't done at all
# 30551         Haven't done at all      Haven't done at all
# 2371                          NaN                      NaN
#
#             StackOverflowAnswer StackOverflowMetaChat  \
# Respondent
# 31601             Several times   Haven't done at all
# 1697              Once or twice   Haven't done at all
# 27944             Once or twice   Haven't done at all
# 18238             Once or twice   Haven't done at all
# 6744              Several times   Haven't done at all
# 41399       Haven't done at all   Haven't done at all
# 32623             Several times   Haven't done at all
# 6718              Once or twice         Several times
# 30551       Haven't done at all   Haven't done at all
# 2371                        NaN                   NaN
#
#            StackOverflowAdsRelevant StackOverflowAdsDistracting  \
# Respondent
# 31601             Strongly disagree              Somewhat agree
# 1697                       Disagree                    Disagree
# 27944                      Disagree                    Disagree
# 18238                      Disagree                    Disagree
# 6744                 Somewhat agree                    Disagree
# 41399                         Agree                       Agree
# 32623                Somewhat agree                       Agree
# 6718                 Somewhat agree           Strongly disagree
# 30551                Somewhat agree              Somewhat agree
# 2371                            NaN                         NaN
#
#            StackOverflowModeration StackOverflowCommunity  \
# Respondent
# 31601               Strongly agree         Somewhat agree
# 1697                      Disagree               Disagree
# 27944                     Disagree               Disagree
# 18238            Strongly disagree      Strongly disagree
# 6744             Strongly disagree         Strongly agree
# 41399                     Disagree         Somewhat agree
# 32623                        Agree         Somewhat agree
# 6718             Strongly disagree         Strongly agree
# 30551                          NaN               Disagree
# 2371                           NaN                    NaN
#
#            StackOverflowHelpful StackOverflowBetter StackOverflowWhatDo  \
# Respondent
# 31601                     Agree               Agree               Agree
# 1697             Strongly agree      Strongly agree               Agree
# 27944                     Agree               Agree            Disagree
# 18238            Strongly agree      Strongly agree      Somewhat agree
# 6744             Strongly agree      Strongly agree      Strongly agree
# 41399                     Agree               Agree               Agree
# 32623            Somewhat agree      Somewhat agree            Disagree
# 6718                      Agree      Strongly agree      Somewhat agree
# 30551                     Agree      Strongly agree               Agree
# 2371                        NaN                 NaN                 NaN
#
#            StackOverflowMakeMoney  Gender HighestEducationParents  \
# Respondent
# 31601                       Agree    Male   A professional degree
# 1697                     Disagree    Male             High school
# 27944                    Disagree    Male       A master's degree
# 18238                    Disagree    Male             High school
# 6744            Strongly disagree  Female       A doctoral degree
# 41399                    Disagree    Male     A bachelor's degree
# 32623                    Disagree    Male       A master's degree
# 6718                     Disagree    Male       A doctoral degree
# 30551                         NaN     NaN                     NaN
# 2371                          NaN     NaN                     NaN
#
#                                     Race         SurveyLong  \
# Respondent
# 31601                         East Asian     Strongly agree
# 1697        White or of European descent           Disagree
# 27944                        South Asian     Strongly agree
# 18238       White or of European descent     Somewhat agree
# 6744        White or of European descent  Strongly disagree
# 41399       White or of European descent           Disagree
# 32623       White or of European descent              Agree
# 6718                         South Asian           Disagree
# 30551                                NaN                NaN
# 2371                                 NaN                NaN
#
#            QuestionsInteresting QuestionsConfusing InterestedAnswers  \
# Respondent
# 31601            Somewhat agree           Disagree    Strongly agree
# 1697                      Agree           Disagree             Agree
# 27944            Somewhat agree           Disagree             Agree
# 18238            Somewhat agree  Strongly disagree    Strongly agree
# 6744                      Agree  Strongly disagree    Strongly agree
# 41399                     Agree           Disagree    Strongly agree
# 32623            Somewhat agree           Disagree    Strongly agree
# 6718             Somewhat agree           Disagree    Somewhat agree
# 30551                       NaN                NaN               NaN
# 2371                        NaN                NaN               NaN
#
#               Salary ExpectedSalary
# Respondent
# 31601       197000.0            NaN
# 1697        195000.0            NaN
# 27944       195000.0            NaN
# 18238       195000.0            NaN
# 6744        195000.0            NaN
# 41399       195000.0            NaN
# 32623       194000.0            NaN
# 6718        193750.0            NaN
# 30551       193000.0            NaN
# 2371        192000.0            NaN
#
# [10 rows x 153 columns]

# %%
df.nsmallest(10, 'Salary')
# Out:
#                       Professional               ProgramHobby    Country  \
# Respondent
# 51145       Professional developer  Yes, I program as a hobby  Australia
# 23954       Professional developer  Yes, I program as a hobby   Colombia
# 2952        Professional developer  Yes, I program as a hobby      India
# 4518        Professional developer                         No      India
# 44842       Professional developer  Yes, I program as a hobby      Japan
# 23908       Professional developer                  Yes, both     Sweden
# 9083        Professional developer                  Yes, both      India
# 23415       Professional developer  Yes, I program as a hobby      India
# 30628       Professional developer                  Yes, both      India
# 29460       Professional developer                  Yes, both      India
#
#                 University    EmploymentStatus  \
# Respondent
# 51145                   No  Employed full-time
# 23954       Yes, part-time  Employed full-time
# 2952                    No  Employed full-time
# 4518        Yes, full-time  Employed full-time
# 44842                   No  Employed full-time
# 23908                   No  Employed full-time
# 9083                    No  Employed full-time
# 23415       Yes, full-time  Employed full-time
# 30628                   No  Employed full-time
# 29460                   No  Employed full-time
#
#                                               FormalEducation  \
# Respondent
# 51145                                       Bachelor's degree
# 23954       Some college/university study without earning ...
# 2952                                        Bachelor's degree
# 4518                                        Bachelor's degree
# 44842                                       Bachelor's degree
# 23908                                        Secondary school
# 9083                                          Master's degree
# 23415                                         Master's degree
# 30628                                       Bachelor's degree
# 29460                                         Master's degree
#
#                                            MajorUndergrad  \
# Respondent
# 51145                        Fine arts or performing arts
# 23954            Computer science or software engineering
# 2952        A non-computer-focused engineering discipline
# 4518             Computer science or software engineering
# 44842                                    A social science
# 23908                                                 NaN
# 9083             Computer science or software engineering
# 23415            Computer science or software engineering
# 30628            Computer science or software engineering
# 29460             Computer programming or Web development
#
#                                                    HomeRemote  \
# Respondent
# 51145       Less than half the time, but at least one day ...
# 23954                                   A few days each month
# 2952                                    A few days each month
# 4518                                    A few days each month
# 44842                                                   Never
# 23908                                   A few days each month
# 9083                                         It's complicated
# 23415       All or almost all the time (I'm full-time remote)
# 30628       Less than half the time, but at least one day ...
# 29460                                   A few days each month
#
#                          CompanySize  \
# Respondent
# 51145             10 to 19 employees
# 23954             10 to 19 employees
# 2952         Fewer than 10 employees
# 4518        5,000 to 9,999 employees
# 44842           100 to 499 employees
# 23908        Fewer than 10 employees
# 9083         Fewer than 10 employees
# 23415             20 to 99 employees
# 30628        Fewer than 10 employees
# 29460       1,000 to 4,999 employees
#
#                                                   CompanyType  \
# Respondent
# 51145                                    Pre-series A startup
# 23954       Privately-held limited company, not in startup...
# 2952                                     Pre-series A startup
# 4518                                                      NaN
# 44842       Sole proprietorship or partnership, not in sta...
# 23908                                    Pre-series A startup
# 9083                                           Something else
# 23415       Privately-held limited company, not in startup...
# 30628       Privately-held limited company, not in startup...
# 29460                                            I don't know
#
#                 YearsProgram     YearsCodedJob YearsCodedJobPast  \
# Respondent
# 51145       20 or more years    17 to 18 years               NaN
# 23954           6 to 7 years      3 to 4 years               NaN
# 2952          16 to 17 years     9 to 10 years               NaN
# 4518                     NaN               NaN               NaN
# 44842           1 to 2 years      1 to 2 years               NaN
# 23908           4 to 5 years      2 to 3 years               NaN
# 9083            5 to 6 years  Less than a year               NaN
# 23415           3 to 4 years      2 to 3 years               NaN
# 30628           4 to 5 years      1 to 2 years               NaN
# 29460         17 to 18 years      2 to 3 years               NaN
#
#                                                 DeveloperType  \
# Respondent
# 51145                                           Web developer
# 23954                         Web developer; Mobile developer
# 2952                          Web developer; Mobile developer
# 4518                           Desktop applications developer
# 44842           DevOps specialist; Quality assurance engineer
# 23908                                           Web developer
# 9083                                            Web developer
# 23415       Web developer; Mobile developer; Desktop appli...
# 30628                                           Web developer
# 29460                                           Web developer
#
#                     WebDeveloperType MobileDeveloperType NonDeveloperType  \
# Respondent
# 51145       Full stack Web developer                 NaN              NaN
# 23954                            NaN                 NaN              NaN
# 2952                             NaN                 NaN              NaN
# 4518                             NaN                 NaN              NaN
# 44842                            NaN                 NaN              NaN
# 23908        Front-end Web developer                 NaN              NaN
# 9083          Back-end Web developer                 NaN              NaN
# 23415                            NaN                 NaN              NaN
# 30628       Full stack Web developer                 NaN              NaN
# 29460       Full stack Web developer                 NaN              NaN
#
#             CareerSatisfaction  JobSatisfaction ExCoderReturn ExCoderNotForMe  \
# Respondent
# 51145                      5.0              4.0           NaN             NaN
# 23954                      8.0              9.0           NaN             NaN
# 2952                       9.0             10.0           NaN             NaN
# 4518                       8.0              8.0           NaN             NaN
# 44842                      8.0              8.0           NaN             NaN
# 23908                      6.0              7.0           NaN             NaN
# 9083                       7.0              6.0           NaN             NaN
# 23415                     10.0             10.0           NaN             NaN
# 30628                      6.0              5.0           NaN             NaN
# 29460                      3.0              3.0           NaN             NaN
#
#            ExCoderBalance ExCoder10Years ExCoderBelonged ExCoderSkills  \
# Respondent
# 51145                 NaN            NaN             NaN           NaN
# 23954                 NaN            NaN             NaN           NaN
# 2952                  NaN            NaN             NaN           NaN
# 4518                  NaN            NaN             NaN           NaN
# 44842                 NaN            NaN             NaN           NaN
# 23908                 NaN            NaN             NaN           NaN
# 9083                  NaN            NaN             NaN           NaN
# 23415                 NaN            NaN             NaN           NaN
# 30628                 NaN            NaN             NaN           NaN
# 29460                 NaN            NaN             NaN           NaN
#
#            ExCoderWillNotCode ExCoderActive  \
# Respondent
# 51145                     NaN           NaN
# 23954                     NaN           NaN
# 2952                      NaN           NaN
# 4518                      NaN           NaN
# 44842                     NaN           NaN
# 23908                     NaN           NaN
# 9083                      NaN           NaN
# 23415                     NaN           NaN
# 30628                     NaN           NaN
# 29460                     NaN           NaN
#
#                                       PronounceGIF  ProblemSolving  \
# Respondent
# 51145                 With a soft "g," like "jiff"             NaN
# 23954                 With a hard "g," like "gift"           Agree
# 2952                  With a soft "g," like "jiff"             NaN
# 4518                  With a soft "g," like "jiff"             NaN
# 44842                 With a hard "g," like "gift"  Somewhat agree
# 23908                 With a hard "g," like "gift"             NaN
# 9083        Enunciating each letter: "gee eye eff"           Agree
# 23415                               Some other way  Somewhat agree
# 30628                 With a soft "g," like "jiff"           Agree
# 29460                 With a soft "g," like "jiff"           Agree
#
#             BuildingThings LearningNewTech      BoringDetails     JobSecurity  \
# Respondent
# 51145                  NaN             NaN                NaN             NaN
# 23954                Agree           Agree     Somewhat agree  Somewhat agree
# 2952                   NaN             NaN                NaN             NaN
# 4518                   NaN             NaN                NaN             NaN
# 44842       Somewhat agree  Somewhat agree     Somewhat agree  Somewhat agree
# 23908                  NaN             NaN                NaN             NaN
# 9083                 Agree  Strongly agree     Somewhat agree           Agree
# 23415                Agree  Somewhat agree     Somewhat agree  Somewhat agree
# 30628                Agree           Agree  Strongly disagree           Agree
# 29460                Agree           Agree     Somewhat agree           Agree
#
#            DiversityImportant      AnnoyingUI FriendsDevelopers  \
# Respondent
# 51145                     NaN             NaN               NaN
# 23954                   Agree  Somewhat agree             Agree
# 2952                      NaN             NaN               NaN
# 4518                      NaN             NaN               NaN
# 44842          Somewhat agree  Somewhat agree    Somewhat agree
# 23908                     NaN             NaN               NaN
# 9083           Somewhat agree  Somewhat agree          Disagree
# 23415          Somewhat agree        Disagree             Agree
# 30628                   Agree  Somewhat agree             Agree
# 29460          Somewhat agree           Agree             Agree
#
#              RightWrongWay UnderstandComputers     SeriousWork  \
# Respondent
# 51145                  NaN                 NaN             NaN
# 23954             Disagree            Disagree        Disagree
# 2952                   NaN                 NaN             NaN
# 4518                   NaN                 NaN             NaN
# 44842       Somewhat agree      Somewhat agree  Somewhat agree
# 23908                  NaN                 NaN             NaN
# 9083                 Agree               Agree           Agree
# 23415             Disagree            Disagree        Disagree
# 30628                Agree      Strongly agree           Agree
# 29460                Agree      Somewhat agree           Agree
#
#            InvestTimeTools     WorkPayCare KinshipDevelopers  ...  \
# Respondent                                                    ...
# 51145                  NaN             NaN               NaN  ...
# 23954       Somewhat agree        Disagree             Agree  ...
# 2952                   NaN             NaN               NaN  ...
# 4518                   NaN             NaN               NaN  ...
# 44842       Somewhat agree  Somewhat agree    Somewhat agree  ...
# 23908                  NaN             NaN               NaN  ...
# 9083                 Agree        Disagree    Somewhat agree  ...
# 23415       Somewhat agree  Somewhat agree    Somewhat agree  ...
# 30628                Agree        Disagree    Somewhat agree  ...
# 29460       Somewhat agree        Disagree    Somewhat agree  ...
#
#            EquipmentSatisfiedStorage EquipmentSatisfiedRW   InfluenceInternet  \
# Respondent
# 51145             Somewhat satisfied       Very satisfied  Somewhat satisfied
# 23954           Not at all satisfied   Somewhat satisfied           Satisfied
# 2952                  Very satisfied            Satisfied           Satisfied
# 4518                             NaN                  NaN                 NaN
# 44842                            NaN                  NaN                 NaN
# 23908                            NaN                  NaN                 NaN
# 9083                  Very satisfied       Very satisfied      Very satisfied
# 23415                 Very satisfied       Very satisfied      Very satisfied
# 30628                      Satisfied   Somewhat satisfied  Somewhat satisfied
# 29460                      Satisfied   Not very satisfied  Not very satisfied
#
#                      InfluenceWorkstation              InfluenceHardware  \
# Respondent
# 51145       I am the final decision maker  I am the final decision maker
# 23954                  Not much influence                 Some influence
# 2952                  No influence at all            No influence at all
# 4518                                  NaN                            NaN
# 44842                                 NaN                            NaN
# 23908                                 NaN                            NaN
# 9083                   A lot of influence                 Some influence
# 23415                      Some influence  I am the final decision maker
# 30628                  A lot of influence             A lot of influence
# 29460                  A lot of influence             A lot of influence
#
#                          InfluenceServers             InfluenceTechStack  \
# Respondent
# 51145       I am the final decision maker  I am the final decision maker
# 23954                  A lot of influence                 Some influence
# 2952                  No influence at all            No influence at all
# 4518                                  NaN                            NaN
# 44842                                 NaN                            NaN
# 23908                                 NaN                            NaN
# 9083                       Some influence             Not much influence
# 23415       I am the final decision maker                 Some influence
# 30628                      Some influence                 Some influence
# 29460                  A lot of influence             A lot of influence
#
#                         InfluenceDeptTech    InfluenceVizTools  \
# Respondent
# 51145       I am the final decision maker   A lot of influence
# 23954                  A lot of influence   Not much influence
# 2952                  No influence at all  No influence at all
# 4518                                  NaN                  NaN
# 44842                                 NaN                  NaN
# 23908                                 NaN                  NaN
# 9083                  No influence at all       Some influence
# 23415                      Some influence       Some influence
# 30628                      Some influence       Some influence
# 29460                  A lot of influence  No influence at all
#
#                         InfluenceDatabase                 InfluenceCloud  \
# Respondent
# 51145       I am the final decision maker  I am the final decision maker
# 23954                  A lot of influence             A lot of influence
# 2952                  No influence at all            No influence at all
# 4518                                  NaN                            NaN
# 44842                                 NaN                            NaN
# 23908                                 NaN                            NaN
# 9083                       Some influence             Not much influence
# 23415       I am the final decision maker                 Some influence
# 30628                  A lot of influence             A lot of influence
# 29460                  A lot of influence             A lot of influence
#
#                      InfluenceConsultants           InfluenceRecruitment  \
# Respondent
# 51145       I am the final decision maker  I am the final decision maker
# 23954                      Some influence             Not much influence
# 2952                  No influence at all            No influence at all
# 4518                                  NaN                            NaN
# 44842                                 NaN                            NaN
# 23908                                 NaN                            NaN
# 9083                   Not much influence            No influence at all
# 23415                  A lot of influence  I am the final decision maker
# 30628                                 NaN                 Some influence
# 29460                  A lot of influence             A lot of influence
#
#                    InfluenceCommunication  \
# Respondent
# 51145       I am the final decision maker
# 23954                  Not much influence
# 2952                  No influence at all
# 4518                                  NaN
# 44842                                 NaN
# 23908                                 NaN
# 9083                   Not much influence
# 23415                      Some influence
# 30628                      Some influence
# 29460                  A lot of influence
#
#                                        StackOverflowDescribes  \
# Respondent
# 51145       I have a login for Stack Overflow, but haven't...
# 23954       I have a login for Stack Overflow, but haven't...
# 2952        I have a login for Stack Overflow, but haven't...
# 4518        I've visited Stack Overflow, but haven't logge...
# 44842       I've visited Stack Overflow, but haven't logge...
# 23908       I have created a CV or Developer Story on Stac...
# 9083        I have created a CV or Developer Story on Stac...
# 23415                                                     NaN
# 30628       I have a login for Stack Overflow, but haven't...
# 29460       I have created a CV or Developer Story on Stac...
#
#            StackOverflowSatisfaction  \
# Respondent
# 51145                           10.0
# 23954                           10.0
# 2952                             7.0
# 4518                             NaN
# 44842                            5.0
# 23908                            5.0
# 9083                            10.0
# 23415                            NaN
# 30628                            7.0
# 29460                            3.0
#
#                                          StackOverflowDevices  \
# Respondent
# 51145                                                 Desktop
# 23954                                                     NaN
# 2952                                                      NaN
# 4518                                                      NaN
# 44842       Desktop; iOS browser; iOS app; Android browser...
# 23908       Desktop; iOS browser; Android browser; Android...
# 9083                                                  Desktop
# 23415                                                     NaN
# 30628                                    Desktop; iOS browser
# 29460                                                 Desktop
#
#            StackOverflowFoundAnswer StackOverflowCopiedCode  \
# Respondent
# 51145       At least once each week     Haven't done at all
# 23954                           NaN                     NaN
# 2952                            NaN                     NaN
# 4518                            NaN                     NaN
# 44842                 Several times           Several times
# 23908       At least once each week           Once or twice
# 9083         At least once each day  At least once each day
# 23415                           NaN                     NaN
# 30628                 Several times           Several times
# 29460                 Once or twice     Haven't done at all
#
#            StackOverflowJobListing StackOverflowCompanyPage  \
# Respondent
# 51145          Haven't done at all      Haven't done at all
# 23954                          NaN                      NaN
# 2952                           NaN                      NaN
# 4518                           NaN                      NaN
# 44842                Several times            Several times
# 23908          Haven't done at all      Haven't done at all
# 9083                 Several times            Once or twice
# 23415                          NaN                      NaN
# 30628          Haven't done at all      Haven't done at all
# 29460                Once or twice            Once or twice
#
#            StackOverflowJobSearch StackOverflowNewQuestion  \
# Respondent
# 51145         Haven't done at all            Once or twice
# 23954                         NaN                      NaN
# 2952                          NaN                      NaN
# 4518                          NaN                      NaN
# 44842               Several times            Several times
# 23908         Haven't done at all            Once or twice
# 9083                Several times            Once or twice
# 23415                         NaN                      NaN
# 30628         Haven't done at all            Once or twice
# 29460         Haven't done at all      Haven't done at all
#
#             StackOverflowAnswer StackOverflowMetaChat  \
# Respondent
# 51145       Haven't done at all   Haven't done at all
# 23954                       NaN                   NaN
# 2952                        NaN                   NaN
# 4518                        NaN                   NaN
# 44842             Several times         Several times
# 23908             Several times   Haven't done at all
# 9083              Once or twice   Haven't done at all
# 23415                       NaN                   NaN
# 30628       Haven't done at all   Haven't done at all
# 29460       Haven't done at all         Once or twice
#
#            StackOverflowAdsRelevant StackOverflowAdsDistracting  \
# Respondent
# 51145                      Disagree           Strongly disagree
# 23954                           NaN                         NaN
# 2952                            NaN                         NaN
# 4518                            NaN                         NaN
# 44842                Somewhat agree              Somewhat agree
# 23908                           NaN                    Disagree
# 9083                 Somewhat agree                    Disagree
# 23415                           NaN                         NaN
# 30628                Somewhat agree                    Disagree
# 29460                           NaN                         NaN
#
#            StackOverflowModeration StackOverflowCommunity  \
# Respondent
# 51145            Strongly disagree         Somewhat agree
# 23954                          NaN                    NaN
# 2952                           NaN                    NaN
# 4518                           NaN                    NaN
# 44842               Somewhat agree         Somewhat agree
# 23908                     Disagree         Somewhat agree
# 9083                Somewhat agree         Somewhat agree
# 23415                          NaN                    NaN
# 30628                     Disagree         Somewhat agree
# 29460                          NaN                    NaN
#
#            StackOverflowHelpful StackOverflowBetter StackOverflowWhatDo  \
# Respondent
# 51145            Strongly agree      Strongly agree      Strongly agree
# 23954                       NaN                 NaN                 NaN
# 2952                        NaN                 NaN                 NaN
# 4518                        NaN                 NaN                 NaN
# 44842            Somewhat agree      Somewhat agree      Somewhat agree
# 23908                     Agree      Somewhat agree      Somewhat agree
# 9083                      Agree               Agree               Agree
# 23415                       NaN                 NaN                 NaN
# 30628                     Agree      Strongly agree      Somewhat agree
# 29460                       NaN                 NaN                 NaN
#
#            StackOverflowMakeMoney  Gender  \
# Respondent
# 51145           Strongly disagree    Male
# 23954                         NaN     NaN
# 2952                          NaN     NaN
# 4518                          NaN     NaN
# 44842              Somewhat agree  Female
# 23908                    Disagree    Male
# 9083                     Disagree  Female
# 23415                         NaN     NaN
# 30628              Somewhat agree    Male
# 29460                         NaN     NaN
#
#                                       HighestEducationParents  \
# Respondent
# 51145                                     A bachelor's degree
# 23954                                                     NaN
# 2952                                                      NaN
# 4518                                                      NaN
# 44842                                     A bachelor's degree
# 23908                                     A bachelor's degree
# 9083                                      A bachelor's degree
# 23415                                                     NaN
# 30628       Some college/university study, no bachelor's d...
# 29460                                                     NaN
#
#                                     Race      SurveyLong QuestionsInteresting  \
# Respondent
# 51145       White or of European descent  Strongly agree                Agree
# 23954                                NaN             NaN                  NaN
# 2952                                 NaN             NaN                  NaN
# 4518                                 NaN             NaN                  NaN
# 44842                         East Asian  Strongly agree       Somewhat agree
# 23908       White or of European descent        Disagree                Agree
# 9083                                 NaN           Agree                Agree
# 23415                                NaN             NaN                  NaN
# 30628                         East Asian  Strongly agree       Strongly agree
# 29460                                NaN             NaN                  NaN
#
#            QuestionsConfusing InterestedAnswers    Salary ExpectedSalary
# Respondent
# 51145       Strongly disagree    Strongly agree  0.000000            NaN
# 23954                     NaN               NaN  0.000000            NaN
# 2952                      NaN               NaN  0.000000            NaN
# 4518                      NaN               NaN  0.000000            NaN
# 44842                Disagree    Strongly agree  0.000000            NaN
# 23908                Disagree    Strongly agree  0.000000            NaN
# 9083           Somewhat agree             Agree  0.014682            NaN
# 23415                     NaN               NaN  0.029364            NaN
# 30628                Disagree             Agree  0.044046            NaN
# 29460                     NaN               NaN  0.044046            NaN
#
# [10 rows x 153 columns]
