# %%
import pandas as pd
df = pd.read_excel("stocks.xlsx", header=[0, 1])
df
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)
#              Company Facebook Google Microsoft                      Facebook Google Microsoft
# 0         2017-06-05      155    955        66                         37.10   32.0     30.31
# 1         2017-06-06      150    987        69                         36.98   31.3     30.56
# 2         2017-06-07      153    963        62                         36.78   31.7     30.46
# 3         2017-06-08      155   1000        61                         36.11   31.2     30.11
# 4         2017-06-09      156   1012        66                         37.07   30.0     31.00

# %%
df_stack = df.stack()
df_stack
# Out:
#               Price  Price to earnings ratio (P/E) Unnamed: 0_level_0
# 0 Company       NaN                            NaN         2017-06-05
#   Facebook    155.0                          37.10                NaT
#   Google      955.0                          32.00                NaT
#   Microsoft    66.0                          30.31                NaT
# 1 Company       NaN                            NaN         2017-06-06
#   Facebook    150.0                          36.98                NaT
#   Google      987.0                          31.30                NaT
#   Microsoft    69.0                          30.56                NaT
# 2 Company       NaN                            NaN         2017-06-07
#   Facebook    153.0                          36.78                NaT
#   Google      963.0                          31.70                NaT
#   Microsoft    62.0                          30.46                NaT
# ...

# %%
df_stack.unstack()
# Out:
#     Price                             ... Unnamed: 0_level_0
#   Company Facebook  Google Microsoft  ...            Company Facebook Google Microsoft
# 0     NaN    155.0   955.0      66.0  ...         2017-06-05      NaT    NaT       NaT
# 1     NaN    150.0   987.0      69.0  ...         2017-06-06      NaT    NaT       NaT
# 2     NaN    153.0   963.0      62.0  ...         2017-06-07      NaT    NaT       NaT
# 3     NaN    155.0  1000.0      61.0  ...         2017-06-08      NaT    NaT       NaT
# 4     NaN    156.0  1012.0      66.0  ...         2017-06-09      NaT    NaT       NaT
#
# [5 rows x 12 columns]

# %%
df2 = pd.read_excel("stocks_3_levels.xlsx", header=[0,1,2])
df2
# Out:
#   Unnamed: 0_level_0 Price Ratios                   ... Income Statement
#   Unnamed: 0_level_1        Price                   ...        Net Sales Net Profit
#              Company     Facebook Google Microsoft  ...        Microsoft   Facebook Google Microsoft
# 0            Q1 2016          155    955        66  ...            18.70       0.80   5.43      4.56
# 1            Q2 2016          150    987        69  ...            21.30       0.97   5.89      5.10
# 2            Q3 2016          153    963        62  ...            21.45       1.20   6.10      5.43
# 3            Q4 2016          155   1000        61  ...            21.88       1.67   6.50      5.89
# 4            Q1 2017          156   1012        66  ...            22.34       2.03   6.40      6.09
#
# [5 rows x 13 columns]

# %%
df2.stack(level=0)
# Out:
#                      Net Profit                   ... Price to earnings ratio (P/E)           Unnamed: 0_level_1
#                        Facebook Google Microsoft  ...                        Google Microsoft            Company
# 0 Income Statement         0.80   5.43      4.56  ...                           NaN       NaN                NaN
#   Price Ratios              NaN    NaN       NaN  ...                          32.0     30.31                NaN
#   Unnamed: 0_level_0        NaN    NaN       NaN  ...                           NaN       NaN            Q1 2016
# 1 Income Statement         0.97   5.89      5.10  ...                           NaN       NaN                NaN
#   Price Ratios              NaN    NaN       NaN  ...                          31.3     30.56                NaN
#   Unnamed: 0_level_0        NaN    NaN       NaN  ...                           NaN       NaN            Q2 2016
# ...

# %%
df2.stack(level=2)
# Out:
#             Income Statement           Price Ratios                               Unnamed: 0_level_0
#                   Net Profit Net Sales        Price Price to earnings ratio (P/E) Unnamed: 0_level_1
# 0 Company                NaN       NaN          NaN                           NaN            Q1 2016
#   Facebook              0.80      2.60        155.0                         37.10                NaN
#   Google                5.43     20.00        955.0                         32.00                NaN
#   Microsoft             4.56     18.70         66.0                         30.31                NaN
# 1 Company                NaN       NaN          NaN                           NaN            Q2 2016
#   Facebook              0.97      3.10        150.0                         36.98                NaN
#   Google                5.89     22.00        987.0                         31.30                NaN
# ...
